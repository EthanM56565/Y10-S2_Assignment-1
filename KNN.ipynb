# %%
#imports all the needed packaages for the program 
import sklearn
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn import linear_model, preprocessing

# %%
#links the code to the data 
data = pd.read_csv("car.data")
#attributes to quantify 
le = preprocessing.LabelEncoder()
buying = le.fit_transform(list(data["buying"]))
maint = le.fit_transform(list(data["maint"]))
door = le.fit_transform(list(data["door"]))
persons = le.fit_transform(list(data["persons"]))
lug_boot = le.fit_transform(list(data["lug_boot"]))
safety = le.fit_transform(list(data["safety"]))
cls = le.fit_transform(list(data["class"]))

# %%
#lable 
predict = "class"
#setup our atibutes for the database
X = list(zip(buying, maint, door, persons, lug_boot, safety))
y = list(cls)
#puts data from the graph into sections 
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.1)

model = KNeighborsClassifier(n_neighbors=9)

# %%
#creating the data 
model.fit(x_train, y_train)
acc = model.score(x_test, y_test)
print(acc)

predicted = model.predict(x_test)
names = ["unacc", "acc", "good", "vgood"]
#ploting the data depending on the data 
for x in range(len(predicted)):
    print("Predicted: ", names[predicted[x]], "Data: ", x_test[x], "Actual: ", names[y_test[x]])
    n = model.kneighbors([x_test[x]], 9, True)
    print("N: ", n)
# Out:
# 0.9075144508670521
# Predicted:  good Data:  (1, 0, 0, 2, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1014,  985, 1200, 1102, 1349,   85,  955, 1433,   44]]))
# Predicted:  good Data:  (1, 1, 0, 2, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1016,  531, 1457,   39, 1454,  977,  483,   37,  489]]))
# Predicted:  good Data:  (1, 2, 1, 2, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 946,  718, 1375, 1047,  690,  725,  610,  584, 1003]]))
# Predicted:  good Data:  (3, 3, 1, 2, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 775, 1207,  352,   70, 1411,  389,  602, 1368, 1435]]))
# ...
